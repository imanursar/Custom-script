# %%
import numpy as np
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append(f'E:\gitlab\custom-script\script')
from ursar import describe,fe,interpretable

# %%
# %reload_ext autoreload

# %% [markdown]
# # interpretable model

# %%
data = pd.read_csv(r'E:\gitlab\machine-learning\dataset\FIFA 2018 Statistics.csv')

y = (data['Man of the Match'] == "Yes")  # Convert from string "Yes"/"No" to binary 0/1
feature_names = [i for i in data.columns if data[i].dtype in [np.int64]]
X = data[feature_names]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
my_model = RandomForestClassifier(random_state=0).fit(X_train, y_train)

# %%
zz = interpretable.permut_imp(my_model,1,X_test, y_test,X)
# Out:
# Using TensorFlow backend.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1750
#
#                     &plusmn; 0.0848
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Goal Scored
# ...

# %%
zz
# Out:
# PermutationImportance(estimator=RandomForestClassifier(random_state=0),
#                       random_state=1)
